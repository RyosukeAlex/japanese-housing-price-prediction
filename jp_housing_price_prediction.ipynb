# %%
import pandas as pd

# %%
df_main = pd.read_csv("C:/Kaggle/All_prefectures_buildings_with_migration.csv")

# %%
df_main.head()
# Out:
#                                   Type  City,Town,Ward,Village code  \
# 0  Residential Land(Land and Building)                        20201
# 1  Residential Land(Land and Building)                        20201
# 2  Residential Land(Land and Building)                        20201
# 3  Residential Land(Land and Building)                        20201
# 4  Residential Land(Land and Building)                        20201
#
#           Prefecture     Location  TotalTransactionValue  Area  Frontage  \
# 0  Nagano Prefecture  Nagano City               27000000   175       9.0
# 1  Nagano Prefecture  Nagano City               27000000   125       9.0
# 2  Nagano Prefecture  Nagano City                6500000    90      10.0
# 3  Nagano Prefecture  Nagano City               27000000   135       8.5
# 4  Nagano Prefecture  Nagano City               67000000   340       4.0
#
#    TotalFloorArea  ConstructionYear  BuildingCoverageRatio  ...  \
# 0             100              2024                   60.0  ...
# 1             100              2019                   60.0  ...
# 2              95              1996                   60.0  ...
# 3              80              2021                   60.0  ...
# 4             200              2020                   60.0  ...
#
#    frontage_greater_than_50  AreaGreaterFlag  Region_Chugoku  Region_Hokkaido  \
# 0                     False            False           False            False
# 1                     False            False           False            False
# 2                     False            False           False            False
# 3                     False            False           False            False
# 4                     False            False           False            False
#
#    Region_Kansai  Region_Kanto  Region_Kyushu  Region_Shikoku  Region_Tohoku  \
# 0          False         False          False           False          False
# 1          False         False          False           False          False
# 2          False         False          False           False          False
# 3          False         False          False           False          False
# 4          False         False          False           False          False
#
#    Migration
# 0    20101.0
# 1    20376.0
# 2    20587.0
# 3    20587.0
# 4    22103.0
#
# [5 rows x 32 columns]

# %%
df_location = pd.read_csv("C:/Kaggle/Location_Data.csv")

# %%
df_location.head()
# Out:
#    City,Town,Ward,Village code Prefecture                      Location  \
# 0                       1101.0   Hokkaido       Chuo Ward, Sapporo City
# 1                       1102.0   Hokkaido       Kita Ward, Sapporo City
# 2                       1103.0   Hokkaido    Higashi Ward, Sapporo City
# 3                       1104.0   Hokkaido  Shiroishi Ward, Sapporo City
# 4                       1105.0   Hokkaido   Toyohira Ward, Sapporo City
#
#     latitude   longitude  Distance_to_designated_city Nearest_designated_city  \
# 0  43.055278  141.341111                     1.097647                 Sapporo
# 1  43.090833  141.340833                     2.999743                 Sapporo
# 2  43.076111  141.363611                     1.898291                 Sapporo
# 3  43.047778  141.405000                     5.072653                 Sapporo
# 4  43.013330  141.391110                     6.701987                 Sapporo
#
#    Close_to_Tokyo  Close_to_greater_Tokyo_area  Close_to_designated_city_flag
# 0           False                        False                           True
# 1           False                        False                           True
# 2           False                        False                           True
# 3           False                        False                          False
# 4           False                        False                          False
